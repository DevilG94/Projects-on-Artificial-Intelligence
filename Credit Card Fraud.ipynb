# %% [markdown]
# ## Importing the Libraries;

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ## Importing DataSet;

# %%
data = pd.read_csv("CreditCard.csv")

# %% [markdown]
# ## Shape of Initial Dataset (Row, Column);

# %%
data.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## Heads of Table;

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## Count the empty (NaN, NAN, na) values in each column;

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Look at the Data Types;

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# ## Info about Data;

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## Correlation for Main DataSet;

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %% [markdown]
# ## Draw the Heatmap for Main Dataset;

# %%
plt.figure(figsize=(32,32))
plt.title('Main Data Set of Credit Card')

sns.heatmap(data.astype(float).corr(),linewidths=0.25,vmax=1.0,square=True,
           cmap="YlGnBu", linecolor='black',annot=True)
# Out:
# <Axes: title={'center': 'Main Data Set of Credit Card'}>

# %% [markdown]
# ## Distribution of legit transactions & fraudulent transactions;

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# #### 0 --> Normal Transaction

# %% [markdown]
# #### 1 --> fraudulent transaction

# %%
legit = data[data.Class==0]

fraud = data[data.Class == 1]

# %%
print(legit.shape)
print("--------------")
print(fraud.shape)
# Out:
# (284315, 31)
# --------------
# (492, 31)

# %% [markdown]
# ## Statistical measures of the data;

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Compare the values for both transactions;

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Build a sample dataset containing similar distribution ofnormal transactions and Fraudulent Transactions;

# %% [markdown]
# ### Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# ## Concatenating two DataFrames;

# %%
new_dataset = pd.concat([legit_sample,fraud],axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93425.032520 -0.032303  0.037648  0.006281  0.007308  0.037834
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.115859  0.043055  0.003394 -0.005130  ... -0.019458 -0.031532
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.001654 -0.021195 -0.012149  0.022739 -0.005376 -0.028821  0.033541
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       72.600955
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Correlation for New DataSet;

# %%
new_dataset.corr()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.231276 -0.212329  0.138178 -0.199542  0.271659  0.116453
# V1      0.231276  1.000000 -0.757966  0.875606 -0.614592  0.860541  0.269647
# V2     -0.212329 -0.757966  1.000000 -0.841052  0.654768 -0.772316 -0.278357
# V3      0.138178  0.875606 -0.841052  1.000000 -0.769002  0.855171  0.442237
# V4     -0.199542 -0.614592  0.654768 -0.769002  1.000000 -0.584316 -0.387005
# V5      0.271659  0.860541 -0.772316  0.855171 -0.584316  1.000000  0.258923
# V6      0.116453  0.269647 -0.278357  0.442237 -0.387005  0.258923  1.000000
# V7      0.210931  0.863187 -0.843997  0.883398 -0.698204  0.828652  0.283217
# V8     -0.140982 -0.082193 -0.017811 -0.171680  0.100773 -0.200641 -0.580107
# V9      0.162376  0.626230 -0.696886  0.752718 -0.775386  0.638101  0.368928
# V10     0.203981  0.721236 -0.763901  0.851185 -0.779964  0.746359  0.423823
# ...

# %% [markdown]
# ## Draw the Heatmap for New Dataset;

# %%
plt.figure(figsize=(32,23))
plt.title('New Data Set of Credit Card')

sns.heatmap(new_dataset.astype(float).corr(),linewidths=0.15,vmax=1.0,square=True,
           cmap="tab20b", linecolor='black',annot=True)
# Out:
# <Axes: title={'center': 'New Data Set of Credit Card'}>

# %% [markdown]
# ## Splitting the data into Features & Targets;

# %%
X = new_dataset.drop(columns = 'Class',axis = 1)

Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 105349   69480.0  1.257811 -1.123614  0.767909 -2.168443 -1.682945 -0.463967
# 210128  137853.0 -0.736735  1.229879 -0.799841 -0.345259  0.990098  0.195586
# 100802   67629.0 -3.270745 -3.445269  1.632516 -0.487164  0.337698 -0.756208
# 156066  107188.0 -0.509555  0.729167  2.366825 -0.102551  0.017708 -0.280573
# 248122  153799.0 -1.446716  0.034892  1.218161 -0.208565  1.443437 -1.375944
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 105349    0
# 210128    0
# 100802    0
# 156066    0
# 248122    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# ## Spliting the DataSet into Training Set & Test Set;

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 0)

# %% [markdown]
# ## Logistic Regression;

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression(random_state=0)

LR.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ## SVM (Support Vector Mechanism);

# %%
from sklearn.svm import SVC

SVM_L = SVC(kernel='linear', random_state = 0)

SVM_L.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ## Naive Bayes Algorithm using GaussianNB;

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()
NB.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Decision Tree Classifier;

# %%
from sklearn.tree import DecisionTreeClassifier

DTree = DecisionTreeClassifier(random_state = 0)
DTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(random_state = 0)
RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ## Data Prediction ;

# %%
y_pred_1 = LR.predict(x_test)

# y_pred_2 = KNN.predict(x_test)

y_pred_3 = SVM_L.predict(x_test)

y_pred_4 = NB.predict(x_test)

y_pred_5 = DTree.predict(x_test)

y_pred_6 = RFC.predict(x_test)

# %% [markdown]
# ## Accuracy and Confusion Matrix;

# %%
ACY1 = accuracy_score(y_test, y_pred_1)
print("Accuracy for Logistic Regression =>",100*ACY1,"%")
CFM1 = confusion_matrix(y_test, y_pred_1)
print("Confusion Matrix for Logistic Regression =>")
print(CFM1)

print("--------------------------------------------------------------------")

ACY3 = accuracy_score(y_test, y_pred_3)
print("Accuracy for SVM =>",100*ACY3,"%")

CFM3 = confusion_matrix(y_test, y_pred_3)
print("Confusion Matrix for SVM =>")

print(CFM3)

print("--------------------------------------------------------------------")

ACY4 = accuracy_score(y_test, y_pred_4)
print("Accuracy for Naive Bayes Algorithm =>",100*ACY4,"%")

CFM4 = confusion_matrix(y_test, y_pred_4)
print("Confusion Matrix for Naive Bayes Algorithm =>")

print(CFM4)

print("--------------------------------------------------------------------")

ACY5 = accuracy_score(y_test, y_pred_5)
print("Accuracy for Dicision Tree Classifier =>",100*ACY5,"%")

CFM5 = confusion_matrix(y_test, y_pred_5)
print("Confusion Matrix Dicision Tree Classifier =>")

print(CFM5)

print("--------------------------------------------------------------------")

ACY6 = accuracy_score(y_test, y_pred_6)
print("Accuracy for Random Forest Classifier =>",100*ACY6,"%")

CFM6 = confusion_matrix(y_test, y_pred_6)
print("Confusion Random Forest Classifier =>")

print(CFM6)

print("--------------------------------------------------------------------")
# Out:
# Accuracy for Logistic Regression => 93.58108108108108 %
# Confusion Matrix for Logistic Regression =>
# [[142   5]
#  [ 14 135]]
# --------------------------------------------------------------------
# Accuracy for SVM => 87.83783783783784 %
# Confusion Matrix for SVM =>
# [[147   0]
#  [ 36 113]]
# --------------------------------------------------------------------
# Accuracy for Naive Bayes Algorithm => 84.12162162162163 %
# Confusion Matrix for Naive Bayes Algorithm =>
# [[147   0]
#  [ 47 102]]
# --------------------------------------------------------------------
# Accuracy for Dicision Tree Classifier => 90.2027027027027 %
# Confusion Matrix Dicision Tree Classifier =>
# [[134  13]
#  [ 16 133]]
# --------------------------------------------------------------------
# Accuracy for Random Forest Classifier => 92.56756756756756 %
# Confusion Random Forest Classifier =>
# [[143   4]
#  [ 18 131]]
# --------------------------------------------------------------------

# %% [markdown]
# ## Visualization of All Confusion Matrices;

# %%
sns.heatmap(CFM1, annot=True, fmt='g', cmap='Pastel1_r')
plt.ylabel('Prediction Data',fontsize=12)
plt.xlabel('Actual Data',fontsize=12)
plt.title('Confusion Matrix for Logistic Regression',fontsize=14)
plt.show()
print("-------------------------------------------------------------------")

sns.heatmap(CFM3, annot=True, fmt='g', cmap='Set3')
plt.ylabel('Prediction Data',fontsize=12)
plt.xlabel('Actual Data',fontsize=12)
plt.title('Confusion Matrix for Support Vector Mechanism',fontsize=14)
plt.show()
print("-------------------------------------------------------------------")

sns.heatmap(CFM4, annot=True, fmt='g', cmap='YlGnBu')
plt.ylabel('Prediction Data',fontsize=12)
plt.xlabel('Actual Data',fontsize=12)
plt.title('Confusion Matrix for Naive Bayes Algorithm',fontsize=14)
plt.show()
print("-------------------------------------------------------------------")

sns.heatmap(CFM5, annot=True, fmt='g', cmap='terrain')
plt.ylabel('Prediction Data',fontsize=12)
plt.xlabel('Actual Data',fontsize=12)
plt.title('Confusion Matrix for Decision Tree Classifier',fontsize=14)
plt.show()
print("-------------------------------------------------------------------")

sns.heatmap(CFM6, annot=True, fmt='g', cmap='copper_r')
plt.ylabel('Prediction Data',fontsize=12)
plt.xlabel('Actual Data',fontsize=12)
plt.title('Confusion Matrix for Random Forest Classifier',fontsize=14)
plt.show()
print("-------------------------------------------------------------------")
# Out:
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# -------------------------------------------------------------------

# %% [markdown]
# ## All Accuracies;

# %%
P1 = 100*ACY1

P3 = 100*ACY3
P4 = 100*ACY4
P5 = 100*ACY5
P6 = 100*ACY6

scores= (P1,P3,P4,P5,P6)

algorithms = ["Logistic Regression","Support Vector Mechanism",
              "Naive Bayes Algorithm","Decision Tree Classifier", 
              "Random Forest Classifier"]

for i in range(len(algorithms)):
    print("The Accuracy is using"+" " + algorithms[i]+" is=> "
          +str(scores[i])+" % ")
# Out:
# The Accuracy is using Logistic Regression is=> 93.58108108108108 %
# The Accuracy is using Support Vector Mechanism is=> 87.83783783783784 %
# The Accuracy is using Naive Bayes Algorithm is=> 84.12162162162163 %
# The Accuracy is using Decision Tree Classifier is=> 90.2027027027027 %
# The Accuracy is using Random Forest Classifier is=> 92.56756756756756 %

# %% [markdown]
# ## Visualizations of All Accuracies;

# %%
fig, ax = plt.subplots()

bar_labels = ['Red', 'Cyan', 'Orange', 'Purple', 'Green']

bar_colors = ['tab:red','tab:cyan', 'tab:orange','tab:purple',
              'tab:Green']

Algos = ["L.R","SVM","N.B","D.T.C", "R.F.C"]

ax.bar(Algos, scores, label=bar_labels, color=bar_colors)

ax.set_xlabel('Algorithms ----->')

ax.set_ylabel('Accuracy Score ----->')

ax.set_title('Accuracy for Different Mechine Learning Algorithms')

ax.legend(title='Accuracy')

plt.show()
